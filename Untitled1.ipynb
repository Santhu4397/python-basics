# %% [markdown]
# # Short

# %%
my_array = [5,3,2,1] 

n = len(my_array) # 4
for i in range(n-1): #0,1
    print("I",i)
    for j in range(n-i-1): #0,1,3
        print("J",j)
        print(my_array[j],my_array[j+1]) 
        if my_array[j] > my_array[j+1]: #T,T,T
            my_array[j], my_array[j+1] = my_array[j+1], my_array[j] #[3,5,2,1],[3,2,5,1],[3,2,1,5]
            print("Sorted array1:", my_array)

print("Sorted array:", my_array)
# Out:
# range(0, 3)
# I 0
# J 0
# 5 3
# Sorted array1: [3, 5, 2, 1]
# J 1
# 5 2
# Sorted array1: [3, 2, 5, 1]
# J 2
# 5 1
# Sorted array1: [3, 2, 1, 5]
# I 1
# J 0
# 3 2
# Sorted array1: [2, 3, 1, 5]
# J 1
# 3 1
# Sorted array1: [2, 1, 3, 5]
# I 2
# J 0
# 2 1
# Sorted array1: [1, 2, 3, 5]
# Sorted array: [1, 2, 3, 5]

# %%
def countingSort(arr):
    max_val = max(arr)
    print("max_val: ",max_val)
    count = [0] * (max_val + 1)
    print("count: ",count)
    while len(arr) > 0:
        num = arr.pop(0)
        print("find the number: ",num)
        count[num] += 1
        print("place in count array in particualer index : ",count)

    for i in range(len(count)):
        while count[i] > 0:
            arr.append(i)
            print("append count array with origanl array",arr)
            count[i] -= 1

    return arr

unsortedArr = [4, 2, 2, 6, 3, 3, 1, 6, 5, 2, 3]
sortedArr = countingSort(unsortedArr)
print("Sorted array:", sortedArr)
# Out:
# max_val:  6
# count:  [0, 0, 0, 0, 0, 0, 0]
# find the number:  4
# place in count array in particualer index :  [0, 0, 0, 0, 1, 0, 0]
# find the number:  2
# place in count array in particualer index :  [0, 0, 1, 0, 1, 0, 0]
# find the number:  2
# place in count array in particualer index :  [0, 0, 2, 0, 1, 0, 0]
# find the number:  6
# place in count array in particualer index :  [0, 0, 2, 0, 1, 0, 1]
# find the number:  3
# place in count array in particualer index :  [0, 0, 2, 1, 1, 0, 1]
# find the number:  3
# place in count array in particualer index :  [0, 0, 2, 2, 1, 0, 1]
# find the number:  1
# place in count array in particualer index :  [0, 1, 2, 2, 1, 0, 1]
# find the number:  6
# place in count array in particualer index :  [0, 1, 2, 2, 1, 0, 2]
# find the number:  5
# place in count array in particualer index :  [0, 1, 2, 2, 1, 1, 2]
# find the number:  2
# place in count array in particualer index :  [0, 1, 3, 2, 1, 1, 2]
# find the number:  3
# ...

# %%
myArray = [170, 45, 75, 90, 802, 24, 2, 66]
print("Original array:", myArray)
radixArray = [[], [], [], [], [], [], [], [], [], []]
maxVal = max(myArray)
exp = 1

while maxVal // exp > 0:

    while len(myArray) > 0:
        print("exp: ",exp)
        val = myArray.pop()
        print("value: ",val)
        radixIndex = (val // exp) % 10
        print("radixIndex: ",radixIndex)
        radixArray[radixIndex].append(val)
        print("radixArray: ",radixArray)

    for bucket in radixArray:
        while len(bucket) > 0:
            val = bucket.pop()
            myArray.append(val)
            print("myArray: ",myArray)

    exp *= 10

print("Sorted array:", myArray)
# Out:
# Original array: [170, 45, 75, 90, 802, 24, 2, 66]
# exp:  1
# value:  66
# radixIndex:  6
# radixArray:  [[], [], [], [], [], [], [66], [], [], []]
# exp:  1
# value:  2
# radixIndex:  2
# radixArray:  [[], [], [2], [], [], [], [66], [], [], []]
# exp:  1
# value:  24
# radixIndex:  4
# radixArray:  [[], [], [2], [], [24], [], [66], [], [], []]
# exp:  1
# value:  802
# radixIndex:  2
# radixArray:  [[], [], [2, 802], [], [24], [], [66], [], [], []]
# exp:  1
# value:  90
# radixIndex:  0
# radixArray:  [[90], [], [2, 802], [], [24], [], [66], [], [], []]
# exp:  1
# value:  75
# radixIndex:  5
# radixArray:  [[90], [], [2, 802], [], [24], [75], [66], [], [], []]
# exp:  1
# value:  45
# radixIndex:  5
# radixArray:  [[90], [], [2, 802], [], [24], [75, 45], [66], [], [], []]
# exp:  1
# value:  170
# radixIndex:  0
# radixArray:  [[90, 170], [], [2, 802], [], [24], [75, 45], [66], [], [], []]
# myArray:  [170]
# myArray:  [170, 90]
# myArray:  [170, 90, 802]
# ...

# %%
def mergeSort(arr):
    if len(arr) <= 1:
        return arr

    mid = len(arr) // 2
    leftHalf = arr[:mid]
    rightHalf = arr[mid:]

    sortedLeft = mergeSort(leftHalf)
    sortedRight = mergeSort(rightHalf)

    return merge(sortedLeft, sortedRight)

def merge(left, right):
    result = []
    i = j = 0

    while i < len(left) and j < len(right):
        if left[i] < right[j]:
            result.append(left[i])
            i += 1
        else:
            result.append(right[j])
            j += 1

    result.extend(left[i:])
    result.extend(right[j:])

    return result

unsortedArr = [3, 7, 6, -10, 15, 23.5, 55, -13]
sortedArr = mergeSort(unsortedArr)
print("Sorted array:", sortedArr)
# Out:
# Sorted array: [-13, -10, 3, 6, 7, 15, 23.5, 55]
